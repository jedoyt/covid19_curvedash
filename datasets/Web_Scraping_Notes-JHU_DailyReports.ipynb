# %% [markdown]
# # Web Scraping JHU Daily Reports on COVID-19

# %%
# Import libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests
from datetime import datetime, timedelta

# %% [markdown]
# ## GET list of links to csv files of daily reports

# %%
def get_csv_links():
    '''
    Fetches all links to csv files of daily reports
    and returns it as a list
    '''
    # URL containing list of csv files of daily reports
    url = "https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports"

    # Create requests object: res
    res = requests.get(url)
    res.raise_for_status()

    # Create a Beautiful Soup object: soup
    soup = BeautifulSoup(res.text,'lxml')
    
    # Get table rows containing links to csv files
    table_rows = soup.table.tbody.find_all('tr', class_="js-navigation-item")[1:-1]
    
    # Set url prefix for the csv file links
    href_prefix = 'https://github.com'
    
    return [href_prefix + table_rows[i].span.a.get('href') for i in range(len(table_rows))]

# %%
get_csv_links()
# Out:
# ['https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-23-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-24-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-25-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-26-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-27-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-28-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-29-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-30-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-31-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-01-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-02-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-03-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-04-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-05-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-06-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-07-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-08-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-09-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-10-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-11-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-12-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-13-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-14-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-15-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-16-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-17-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-18-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-19-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-20-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-21-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-22-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-23-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-24-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-25-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-26-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-27-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-28-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-29-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-01-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-02-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-03-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-04-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-05-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-06-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-07-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-08-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-09-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-10-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-11-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-12-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-13-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-14-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-15-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-16-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-18-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-19-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-20-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-21-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-22-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-23-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-24-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-25-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-26-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-27-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-28-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-29-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-30-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-31-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-03-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-04-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-05-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-06-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-07-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-08-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-09-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-10-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-11-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-12-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-13-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-14-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-15-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-16-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-17-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-18-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-19-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-20-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-21-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-22-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-23-2020.csv',
#  'https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-24-2020.csv']

# %% [markdown]
# ## Scrape the Table from the csv file page

# %%
def get_day_report_df(csvpage_url):
    '''
    Scrapes the table content of a single csv page link
    to transform and return as a pandas dataframe
    '''
    print("GET request from",csvpage_url)

    # Create requests object: res
    res = requests.get(csvpage_url)
    res.raise_for_status()

    # Create a Beautiful Soup object: soup
    soup = BeautifulSoup(res.text,'lxml')
    
    # Read html string and generate a pandas dataframe
    df = pd.read_html(str(soup.table))[0]

    # Add additional column
    df['ObservationDate'] = '/'.join(csvpage_url[-14:-4].split('-'))
    
    # Rename column 'Country_Region' to 'Country/Region'
    df.rename(columns={'Country_Region':'Country/Region'},inplace=True)
    
    # Fill 'nan' with 0
    df.fillna(value=0,inplace=True)
    
    # Group DataFrame by 'Country/Region'
    df_bycountry = df.groupby(['ObservationDate','Country/Region']).sum().copy()
    df_bycountry.reset_index(inplace=True) # Reset index    
    df_bycountry = df_bycountry[['ObservationDate', # Reduce columns included
                                 'Country/Region',
                                 'Confirmed',
                                 'Deaths',
                                 'Recovered']]
    
    return df_bycountry

# %% [markdown]
# ## Concatenate all daily reports into 1 DataFrame

# %%
def concat_daily_reports():
    '''
    Concatenates all daily reports by using these functions:
        get_csv_links, get_day_report_df
    Generates a csv file with the filename 'covid_19_data.csv'
        This csv file is meant to be cleaned using the function revise_covid19_data()
    Returns a pandas dataframe containing the scraped raw dataset
    '''
    csv_links = get_csv_links()

    df_list = [get_day_report_df(csv_links[i]) for i in range(len(csv_links))]

    df = pd.concat(df_list,axis=0)
    
    #df.to_csv('covid_19_data.csv',index=False)
    
    return df

# %%
df = concat_daily_reports()
# Out:
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-23-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-24-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-25-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-26-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-27-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-28-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-29-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-30-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/01-31-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-01-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-02-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-03-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-04-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-05-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-06-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-07-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-08-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-09-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-10-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-11-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-12-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-13-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-14-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-15-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-16-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-17-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-18-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-19-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-20-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-21-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-22-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-23-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-24-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-25-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-26-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-27-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-28-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/02-29-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-01-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-02-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-03-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-04-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-05-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-06-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-07-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-08-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-09-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-10-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-11-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-12-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-13-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-14-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-15-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-16-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-18-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-19-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-20-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-21-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-22-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-23-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-24-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-25-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-26-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-27-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-28-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-29-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-30-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/03-31-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-03-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-04-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-05-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-06-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-07-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-08-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-09-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-10-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-11-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-12-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-13-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-14-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-15-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-16-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-17-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-18-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-19-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-20-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-21-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-22-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-23-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-24-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-25-2020.csv
# GET request from https://github.com/CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/04-26-2020.csv

# %%
df['Country/Region'].unique()
# Out:
# array(['Hong Kong', 'Japan', 'Macau', 'Mainland China', 'South Korea',
#        'Taiwan', 'Thailand', 'US', 'Australia', 'Brazil', 'Colombia',
#        'Malaysia', 'Mexico', 'Philippines', 'Singapore', 'Vietnam',
#        'France', 'Nepal', 'Canada', 'Cambodia', 'Ivory Coast',
#        'Sri Lanka', 'Germany', 'Finland', 'United Arab Emirates', 'India',
#        'Italy', 'Russia', 'Sweden', 'UK', 'Spain', 'Belgium', 'Others',
#        'Egypt', 'Iran', 'Israel', 'Lebanon', 'Iraq', 'Afghanistan',
#        'Bahrain', 'Kuwait', 'Oman', 'Algeria', 'Austria', 'Croatia',
#        'Switzerland', 'Georgia', 'Greece', 'North Macedonia', 'Norway',
#        'Pakistan', 'Romania', 'Denmark', 'Estonia', 'Netherlands',
#        'San Marino', 'Azerbaijan', 'Belarus', 'Iceland', 'Lithuania',
#        'New Zealand', 'Nigeria', 'North Ireland', 'Ireland', 'Luxembourg',
#        'Monaco', 'Qatar', 'Armenia', 'Czech Republic',
#        'Dominican Republic', 'Ecuador', 'Andorra', 'Indonesia', 'Latvia',
#        'Morocco', 'Portugal', 'Saudi Arabia', 'Senegal', 'Argentina',
#        'Chile', 'Jordan', 'Ukraine', 'Faroe Islands', 'Gibraltar',
#        'Hungary', 'Liechtenstein', 'Poland', 'Saint Barthelemy',
#        'Tunisia', 'Bosnia and Herzegovina', 'Palestine', 'Slovenia',
#        'South Africa', 'Bhutan', 'Cameroon', 'Costa Rica', 'Peru',
#        'Serbia', 'Slovakia', 'Togo', 'Vatican City', 'French Guiana',
#        'Malta', 'Martinique', 'Bangladesh', 'Bulgaria', 'Maldives',
#        'Moldova', 'Paraguay', 'Republic of Ireland', 'Albania', 'Brunei',
#        'Cyprus', 'St. Martin', 'Burkina Faso', 'Channel Islands',
#        'Holy See', 'Hong Kong SAR', 'Iran (Islamic Republic of)',
#        'Macao SAR', 'Mongolia', 'Panama', 'Republic of Korea',
#        'Republic of Moldova', 'Russian Federation', 'Saint Martin',
#        'Taipei and environs', 'Viet Nam',
#        'occupied Palestinian territory', 'Bolivia', 'China',
#        'Congo (Kinshasa)', "Cote d'Ivoire", 'Cruise Ship', 'Czechia',
#        'Honduras', 'Jamaica', 'Korea, South', 'Reunion', 'Taiwan*',
#        'Turkey', 'United Kingdom', 'Cuba', 'Guyana',
#        'Antigua and Barbuda', 'Aruba', 'Cayman Islands', 'Ethiopia',
#        'Guadeloupe', 'Guinea', 'Kazakhstan', 'Kenya', 'Sudan', 'Curacao',
#        'Eswatini', 'Gabon', 'Ghana', 'Guatemala', 'Guernsey', 'Jersey',
#        'Mauritania', 'Namibia', 'Rwanda', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'Seychelles', 'Suriname',
#        'Trinidad and Tobago', 'Uruguay', 'Venezuela',
#        'Central African Republic', 'Congo (Brazzaville)',
#        'Equatorial Guinea', 'Kosovo', 'Uzbekistan', 'Benin', 'Greenland',
#        'Guam', 'Liberia', 'Mayotte', 'Puerto Rico',
#        'Republic of the Congo', 'Somalia', 'Tanzania', 'The Bahamas',
#        'Barbados', 'Montenegro', 'The Gambia', 'Djibouti', 'Gambia, The',
#        'Kyrgyzstan', 'Mauritius', 'Zambia', 'Bahamas, The', 'Chad',
#        'El Salvador', 'Fiji', 'Nicaragua', 'Angola', 'Cabo Verde',
#        'Haiti', 'Madagascar', 'Niger', 'Papua New Guinea', 'Zimbabwe',
#        'Cape Verde', 'East Timor', 'Eritrea', 'Uganda', 'Bahamas',
#        'Dominica', 'Gambia', 'Grenada', 'Mozambique', 'Syria',
#        'Timor-Leste', 'Belize', 'Laos', 'Libya', 'Diamond Princess',
#        'Guinea-Bissau', 'Mali', 'Saint Kitts and Nevis',
#        'West Bank and Gaza', 'Burma', 'MS Zaandam', 'Botswana', 'Burundi',
#        'Sierra Leone', 'Malawi', 'South Sudan', 'Western Sahara',
#        'Sao Tome and Principe', 'Yemen'], dtype=object)
